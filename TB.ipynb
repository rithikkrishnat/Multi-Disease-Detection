# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# %%
data_dir = "./dataset/TB"
train_dir = data_dir + "/train"
test_dir = data_dir + "/test"

# %%
img_height, img_width = 224, 224
batch_size = 32

# %%
data_gen = ImageDataGenerator(
    rescale=1.0/255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

# %%
train_data = data_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)
# Out:
# Found 1921 images belonging to 2 classes.

# %%
val_data = data_gen.flow_from_directory(
    train_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)
# Out:
# Found 479 images belonging to 2 classes.

# %%
test_data_gen = ImageDataGenerator(rescale=1.0/255)
test_data = test_data_gen.flow_from_directory(
    test_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary'
)
# Out:
# Found 608 images belonging to 2 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
# Out:
# C:\Users\Ribhu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
epochs = 20
history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=epochs,
    verbose=1
)
# Out:
# C:\Users\Ribhu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7900 - loss: 0.4730
# C:\Users\Ribhu\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 85s 1s/step - accuracy: 0.7905 - loss: 0.4724 - val_accuracy: 0.8288 - val_loss: 0.3774
# Epoch 2/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8471 - loss: 0.3379 - val_accuracy: 0.8288 - val_loss: 0.4082
# Epoch 3/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8588 - loss: 0.3091 - val_accuracy: 0.8873 - val_loss: 0.2874
# Epoch 4/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 76s 1s/step - accuracy: 0.8961 - loss: 0.2300 - val_accuracy: 0.9165 - val_loss: 0.1969
# Epoch 5/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 75s 1s/step - accuracy: 0.9237 - loss: 0.1711 - val_accuracy: 0.9228 - val_loss: 0.2085
# Epoch 6/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 79s 1s/step - accuracy: 0.8980 - loss: 0.2105 - val_accuracy: 0.9374 - val_loss: 0.1555
# Epoch 7/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9202 - loss: 0.1939 - val_accuracy: 0.9228 - val_loss: 0.1797
# Epoch 8/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 80s 1s/step - accuracy: 0.9319 - loss: 0.1642 - val_accuracy: 0.9332 - val_loss: 0.1597
# Epoch 9/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9310 - loss: 0.1510 - val_accuracy: 0.9186 - val_loss: 0.2153
# Epoch 10/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9259 - loss: 0.1610 - val_accuracy: 0.9395 - val_loss: 0.1902
# Epoch 11/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9465 - loss: 0.1415 - val_accuracy: 0.9290 - val_loss: 0.1774
# Epoch 12/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9449 - loss: 0.1460 - val_accuracy: 0.9603 - val_loss: 0.1157
# Epoch 13/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9548 - loss: 0.1155 - val_accuracy: 0.9457 - val_loss: 0.1466
# Epoch 14/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9449 - loss: 0.1297 - val_accuracy: 0.9541 - val_loss: 0.1124
# Epoch 15/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9537 - loss: 0.1200 - val_accuracy: 0.9749 - val_loss: 0.0876
# Epoch 16/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9600 - loss: 0.1207 - val_accuracy: 0.9353 - val_loss: 0.1651
# Epoch 17/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9463 - loss: 0.1397 - val_accuracy: 0.9457 - val_loss: 0.1405
# Epoch 18/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9467 - loss: 0.1477 - val_accuracy: 0.9499 - val_loss: 0.1385
# Epoch 19/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 78s 1s/step - accuracy: 0.9571 - loss: 0.1391 - val_accuracy: 0.9395 - val_loss: 0.1341
# Epoch 20/20
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - accuracy: 0.9544 - loss: 0.1206 - val_accuracy: 0.9708 - val_loss: 0.0958

# %%
model.save("tb_detection_model.h5")

print("Model saved as tb_detection_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as tb_detection_model.h5
